# %% [markdown]
# <a href="https://colab.research.google.com/github/AKSHAYA404/NLP/blob/main/LAB_ASSIGNMNET_1_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk spacy

# %%
import nltk
import spacy

# %% [markdown]
# Natural Language Processing is an exciting field of Artificial Intelligence.
# It helps computers understand and work with human language.
# Libraries like NLTK and spaCy make NLP tasks easier.

# %%
paragraph = "Natural Language Processing is an exciting field of Artificial Intelligence. It helps computers understand and work with human language. Libraries like NLTK and spaCy make NLP tasks easier."
words = paragraph.split()
print("Number of words:", len(words))
lower_text = paragraph.lower()
print(lower_text)
# Out:
# Number of words: 28
# natural language processing is an exciting field of artificial intelligence. it helps computers understand and work with human language. libraries like nltk and spacy make nlp tasks easier.
